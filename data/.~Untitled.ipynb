# %%
import pandas as pd

# %%
df = pd.read_csv('kostom_pair.csv', sep='\t')

# %%
df[1500:1550]
# Out:
#                                                   sent0  \
# 1500                                   basedows disease
# 1501                   spirit:threshold:pt:meconium:ord
# 1502                                      ileus spastic
# 1503  microscopic examination of specimen from other...
# 1504                      cutrine plus:mcnt:pt:liver:qn
# 1505      hpv probe (hcs):acnc:pt:xxx:ord:probe.amp.sig
# 1506                       hydrocodone:mcnc:pt:urine:qn
# 1507             coccidioides immitis ab:titr:pt:csf:qn
# 1508  macrophages/100 leukocytes:nfr:pt:bronchial:qn...
# 1509               urease^2nd specimen:acnc:pt:tiss:ord
# 1510                african trypanosomiasis unspecified
# 1511                            other specified symptom
# 1512                            nph:mcnc:pt:ser/plas:qn
# 1513  statement of adequacy:imp:pt:cvx/vag:nom:cyto ...
# 1514  acth (adrenocorticotropic hormone):mcnc:pt:pla...
# 1515                               aphasia (due to) nos
# ...
